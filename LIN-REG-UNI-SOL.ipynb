# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
from scipy.stats import shapiro
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
from scipy import stats
def plot_ccpr(model, cols):
    plotn = 0
    rows = 4
    columns = 1
    fig, ax_array = plt.subplots(rows, columns,squeeze=False)
    fig.set_figheight(20)
    fig.set_figwidth(25)
    for i,ax_row in enumerate(ax_array):
        for j,axes in enumerate(ax_row):
            axes.set_title(cols[plotn])
            sm.graphics.plot_ccpr(model, cols[plotn], ax = axes)
            plotn = plotn + 1
    plt.show()
    
def plot_model(df, model):
    influence = model.get_influence()

    df['resid'] = model.resid
    df['fittedvalues'] = model.fittedvalues
    df['resid_std'] = model.resid_pearson
    df['leverage'] = influence.hat_matrix_diag

    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,8))
    plt.style.use('seaborn')

    # Residual against fitted values.
    df.plot.scatter(
        x='fittedvalues', y='resid', ax=axes[0, 0]
    )
    axes[0, 0].axhline(y=0, color='grey', linestyle='dashed')
    axes[0, 0].set_xlabel('Fitted Values')
    axes[0, 0].set_ylabel('Residuals')
    axes[0, 0].set_title('Residuals vs Fitted')

    # qqplot
    sm.qqplot(
        df['resid'], dist=stats.t, fit=True, line='45',
        ax=axes[0, 1], c='#4C72B0'
    )
    axes[0, 1].set_title('Normal Q-Q')

    # The scale-location plot.
    df.plot.scatter(
        x='fittedvalues', y='resid_std', ax=axes[1, 0]
    )
    axes[1, 0].axhline(y=0, color='grey', linestyle='dashed')
    axes[1, 0].set_xlabel('Fitted values')
    axes[1, 0].set_ylabel('Sqrt(|standardized residuals|)')
    axes[1, 0].set_title('Scale-Location')

    # Standardized residuals vs. leverage
    df.plot.scatter(
        x='leverage', y='resid_std', ax=axes[1, 1]
    )
    axes[1, 1].axhline(y=0, color='grey', linestyle='dashed')
    axes[1, 1].set_xlabel('Leverage')
    axes[1, 1].set_ylabel('Sqrt(|standardized residuals|)')
    axes[1, 1].set_title('Residuals vs Leverage')

    plt.tight_layout()
    plt.show()

def clean_data(df):
    d = df.copy()
    d = d.drop(["Date","SNo", "Name", "Symbol"], axis = 1)
    return d

# %%
import glob
files = glob.glob("./data/*")

# %%
ycol = "Close"
xcol = d.columns[[0, 1, 2, 4, 5]]
formula = "Close~" + "+".join(xcol)

# %%
for f in files:
    d = pd.read_csv(f)
    d = d.drop(["Date","SNo", "Name", "Symbol"], axis = 1)
    model = ols(formula = formula, data=d).fit()
    print(f)
    plot_model(d, model)
# Out:
# ./data/coin_NEM.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_EOS.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Monero.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Polkadot.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_USDCoin.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Uniswap.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_BinanceCoin.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Iota.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Aave.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Solana.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Bitcoin.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Cardano.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Tether.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Cosmos.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_ChainLink.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Litecoin.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_XRP.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Ethereum.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Tron.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Stellar.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_CryptocomCoin.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_Dogecoin.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ./data/coin_WrappedBitcoin.csv
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# Best ones: <br>
#     Uniswap <br>
#     Solana <br>

# %%
def plot_cooksd(df):
    plt.figure(figsize=(15, 7))
    plt.scatter(df.index, df.cooks_d)
    plt.xlabel('Index')
    plt.ylabel('Cooks Distance')
    plt.show()
    
def plot_hatvalues(df):
    plt.figure(figsize=(15, 7))
    plt.scatter(df.index, df.hat_diag)
    plt.xlabel('Index')
    plt.ylabel('Hat values')
    plt.show()
    
def analysis(filename, npred):
    d = pd.read_csv(filename)
    to_predict = d.iloc[-npred:,:]
    d = d.iloc[:d.shape[0] - npred,:]
    d = clean_data(d)
    model = ols(formula = formula, data=d).fit()
    #plot_ccpr(model, xcol)
    plot_model(d, model)
    
    influence = model.get_influence()
    df = influence.summary_frame()
    
    print(shapiro(model.resid))
    
    tp = clean_data(to_predict)
    x = tp[tp.columns[[0, 1, 2, 4, 5]]]
    y = tp[tp.columns[[3]]]
    
    plt.figure(figsize=(15, 5))
    plt.plot(model.predict(x))
    plt.plot(y)

# %%
topred = 150

# %%
analysis('./data/coin_Uniswap.csv', topred)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# ShapiroResult(statistic=0.9330444931983948, pvalue=2.8840636332461145e-06)

# %%
analysis('./data/coin_Solana.csv', topred)
# Out:
# ShapiroResult(statistic=0.9029378294944763, pvalue=5.148637592655714e-13)
